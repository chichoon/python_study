# %%
from flask import Flask, render_template, request, redirect
from sof_func import get_jobs as sof_get_jobs
from indeed_func import get_jobs as indeed_get_jobs

app = Flask("Python")

@app.route("/")
def home():
    return render_template("index.html")
#root에 접근했을 때 출력되는 텍스트 (html 형식으로 적으면 html 태그대로 출력됨)
#@는 데코레이터로, 이것이 사용된 라인 바로 아래 줄에서 함수를 찾아서 실행시킴

@app.route("/contact")
def contact():
    return "contact me"
#contact에 접근했을 때 텍스트가 출력되도록 함
#함수 이름은 접근할 페이지 이름과 상관없음

@app.route("/<username>")
def usr(username):
    return f"hello, {username}!"
#<> 는 Placeholder로, 안에 들은 값이 밑의 함수의 인자로 들어간다
#이렇게 입력했을 경우, 127.0.0.1:5000/이름 입력하면 hello, 이름! 이라고 화면에 표시됨

@app.route("/report")
def report():
    word = request.args.get("word")
    #word 에 해당하는 query argument를 가져옴 (form에서 입력받은 값)
    #request.args는 dictionary를 return하므로, get 이용하여 key에 해당하는 value 추출
    if word:
        word = word.lower()
        #word에 값이 존재할 때 소문자로 변환
        jobs = sof_get_jobs(word) + indeed_get_jobs(word)
        print(jobs)
        #
    else:
        return redirect("/")
        #값이 없으면 root로 리다이렉트
    return render_template("report.html", SearchingBy=word)
    #SearchingBy 변수를 report.html에 넘겨주며 실행시킴

app.run(host="127.0.0.1", port="5000")
#repl.it 사용 시에는 host="0.0.0.0"
#vscode 이용하여 localhost 접속시에는 127.0.0.1 (기본값)
# Out:
#  * Serving Flask app "Python" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/Mar/2021 23:22:13] "GET / HTTP/1.1" 200 -
# React Developer Jobs  - Stack Overflow
# ☆Scrapping page 0 :
# ☆Scrapping page 1 :
# ☆Scrapping page 2 :
# ☆Scrapping page 3 :
# ☆Scrapping page 4 :
# ☆Scrapping page 5 :
# ☆Scrapping page 6 :
# ☆Scrapping page 7 :
# ☆Scrapping page 8 :
# ☆Scrapping page 9 :
# ☆Scrapping page 10 :
# ☆Scrapping page 11 :
# ☆Scrapping page 12 :
# ☆Scrapping page 13 :
# ☆Scrapping page 14 :
# ☆Scrapping page 15 :
# ☆Scrapping page 16 :
# ☆Scrapping page 17 :
# ☆Scrapping page 18 :
# ☆Scrapping page 19 :
# ☆Scrapping page 20 :
# ☆Scrapping page 21 :
# ☆Scrapping page 22 :
# ☆Scrapping page 23 :
# ☆Scrapping page 24 :
# ☆Scrapping page 25 :
# ☆Scrapping page 26 :
# ☆Scrapping page 27 :
# ☆Scrapping page 28 :
# ☆Scrapping page 29 :
# ☆Scrapping page 30 :
# ☆Scrapping page 31 :
# ☆Scrapping page 32 :
# ☆Scrapping page 33 :
# ☆Scrapping page 34 :
# ☆Scrapping page 35 :
# ☆Scrapping page 36 :
# ☆Scrapping page 37 :
# ☆Scrapping page 38 :
# ☆Scrapping page 39 :
# ☆Scrapping page 40 :
# ☆Scrapping page 41 :
# ☆Scrapping page 42 :
# ☆Scrapping page 43 :
# ☆Scrapping page 44 :
# ☆Scrapping page 45 :
# ☆Scrapping page 46 :
# ☆Scrapping page 47 :
# ☆Scrapping page 48 :
# ☆Scrapping page 49 :
# ☆Scrapping page 50 :
# ☆Scrapping page 51 :
# ☆Scrapping page 52 :
# ☆Scrapping page 53 :
# ☆Scrapping page 54 :
# ☆Scrapping page 55 :
# ☆Scrapping page 56 :
# ☆Scrapping page 57 :
# ☆Scrapping page 58 :
# ☆Scrapping page 59 :
# ☆Scrapping page 60 :
# ☆Scrapping page 61 :
# ☆Scrapping page 62 :
# ☆Scrapping page 63 :
# ☆Scrapping page 64 :
# ☆Scrapping page 65 :
# ☆Scrapping page 66 :
# 2021년 3월 React 취업, 일자리, 채용
# ★Scrapping page 0 :
# ★Scrapping page 1 :
# ★Scrapping page 2 :
# ★Scrapping page 3 :
# ★Scrapping page 4 :
# 127.0.0.1 - - [02/Mar/2021 23:23:40] "GET /report?word=react HTTP/1.1" 200 -
# [{'title': 'Senior Java Software Engineer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Columbus, OH', 'apply_link': 'https://stackoverflow.com/jobs/512646'}, {'title': 'Senior Electron Engineer', 'company': 'Exodus.io', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/455748'}, {'title': 'Lead Software Engineer at Fintech - remote work option within Germany (m/f/div)', 'company': 'Elinvar GmbH', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/419675'}, {'title': 'Werksstudent Web Entwickler (m/w/d) mit React, HTML, Javascript', 'company': 'Bolinda Labs GmbH', 'location': 'Darmstadt, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/396057'}, {'title': 'Backend Entwickler (m/w/d) mit Spring Boot, Java 11, AWS und Docker gesucht', 'company': 'Bolinda Labs GmbH', 'location': 'Darmstadt, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/264821'}, {'title': 'Full Stack Entwickler (m/w/d) mit React und Spring Boot als Verstärkung gesucht', 'company': 'Bolinda Labs GmbH', 'location': 'Darmstadt, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/252224'}, {'title': 'Web Entwickler (m/w/d) mit React Erfahrung als Verstärkung gesucht', 'company': 'Bolinda Labs GmbH', 'location': 'Darmstadt, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/235595'}, {'title': '(Senior) Frontend Developer (m/f/x)', 'company': 'Clark Germany GmbH', 'location': 'Frankfurt am Main, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/512670'}, {'title': 'Software Tester', 'company': 'Blueprint Genetics', 'location': 'Espoo, Finland', 'apply_link': 'https://stackoverflow.com/jobs/455233'}, {'title': 'Full-Stack Developers', 'company': 'Blueprint Genetics', 'location': 'Espoo, Finland', 'apply_link': 'https://stackoverflow.com/jobs/455231'}, {'title': 'Cloud Engineers', 'company': 'Blueprint Genetics', 'location': 'Espoo, Finland', 'apply_link': 'https://stackoverflow.com/jobs/455234'}, {'title': 'Softwareentwickler (m/w/d)', 'company': 'AM GmbH', 'location': 'Hamburg, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/380999'}, {'title': 'Senior React Developer', 'company': 'Youwe', 'location': 'Rotterdam, Netherlands', 'apply_link': 'https://stackoverflow.com/jobs/512668'}, {'title': 'Fullstack & frontendutvecklare, ICA Försäkring', 'company': 'ICA Gruppen', 'location': 'Solna, Sweden', 'apply_link': 'https://stackoverflow.com/jobs/465943'}, {'title': 'Flutter, Senior Developer', 'company': 'IDT Finland', 'location': 'Helsinki, Finland', 'apply_link': 'https://stackoverflow.com/jobs/432936'}, {'title': 'Senior Full Stack Engineer', 'company': 'Strattic', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/465930'}, {'title': 'Back-end Engineer', 'company': 'CityBldr', 'location': 'No office location', 'apply_link': 'https://stackoverflow.com/jobs/406631'}, {'title': 'Full stack Team Leader', 'company': 'Marketman LTD', 'location': "Ra'anana, Israel", 'apply_link': 'https://stackoverflow.com/jobs/512659'}, {'title': 'Full Stack Java Software Engineer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Columbus, OH', 'apply_link': 'https://stackoverflow.com/jobs/512647'}, {'title': 'Software Engineering', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Tampa, FL', 'apply_link': 'https://stackoverflow.com/jobs/512643'}, {'title': 'Software Engineering-Java Fullstack', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Bengaluru, India', 'apply_link': 'https://stackoverflow.com/jobs/512639'}, {'title': 'Software Engineering', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/512632'}, {'title': 'WM Software Engineer -Java/js Full Stack Developer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/512630'}, {'title': 'Software Engineering', 'company': 'JPMorgan Chase Ban ...
