# %%
from flask import Flask, render_template, request, redirect
from sof_func import get_jobs as sof_get_jobs
from indeed_func import get_jobs as indeed_get_jobs

app = Flask("Python")

db = {}
#fake db

@app.route("/")
def home():
    return render_template("index.html")
#root에 접근했을 때 출력되는 텍스트 (html 형식으로 적으면 html 태그대로 출력됨)
#@는 데코레이터로, 이것이 사용된 라인 바로 아래 줄에서 함수를 찾아서 실행시킴

@app.route("/contact")
def contact():
    return "contact me"
#contact에 접근했을 때 텍스트가 출력되도록 함
#함수 이름은 접근할 페이지 이름과 상관없음

@app.route("/<username>")
def usr(username):
    return f"hello, {username}!"
#<> 는 Placeholder로, 안에 들은 값이 밑의 함수의 인자로 들어간다
#이렇게 입력했을 경우, 127.0.0.1:5000/이름 입력하면 hello, 이름! 이라고 화면에 표시됨

@app.route("/report")
def report():
    word = request.args.get("word")
    #word 에 해당하는 query argument를 가져옴 (form에서 입력받은 값)
    #request.args는 dictionary를 return하므로, get 이용하여 key에 해당하는 value 추출
    if word:
        word = word.lower()
        #word에 값이 존재할 때 소문자로 변환
        fromdb = db.get(word)
        if fromdb:
            #이미 데이터베이스에 word가 존재할 경우
            jobs = fromdb
        else:
            #데이터베이스에 자료가 없을 경우
            jobs = sof_get_jobs(word) + indeed_get_jobs(word)
        db[word] =jobs
        print(jobs)
        #
    else:
        return redirect("/")
        #값이 없으면 root로 리다이렉트
    return render_template("report.html", SearchingBy=word, resultsNum=len(jobs))
    #SearchingBy 변수를 report.html에 넘겨주며 실행시킴

app.run(host="127.0.0.1", port="5000")
#repl.it 사용 시에는 host="0.0.0.0"
#vscode 이용하여 localhost 접속시에는 127.0.0.1 (기본값)
# Out:
#  * Serving Flask app "Python" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Mar/2021 17:27:27] "GET / HTTP/1.1" 200 -
# Golang Developer Jobs  - Stack Overflow
# ☆Scrapping page 0 :
# ☆Scrapping page 1 :
# ☆Scrapping page 2 :
# ☆Scrapping page 3 :
# ☆Scrapping page 4 :
# ☆Scrapping page 5 :
# ☆Scrapping page 6 :
# ☆Scrapping page 7 :
# ☆Scrapping page 8 :
# ☆Scrapping page 9 :
# ☆Scrapping page 10 :
# ☆Scrapping page 11 :
# ☆Scrapping page 12 :
# ☆Scrapping page 13 :
# ☆Scrapping page 14 :
# ☆Scrapping page 15 :
# ☆Scrapping page 16 :
# ☆Scrapping page 17 :
# ☆Scrapping page 18 :
# ☆Scrapping page 19 :
# ☆Scrapping page 20 :
# ☆Scrapping page 21 :
# ☆Scrapping page 22 :
# ☆Scrapping page 23 :
# ☆Scrapping page 24 :
# ☆Scrapping page 25 :
# ☆Scrapping page 26 :
# ☆Scrapping page 27 :
# ☆Scrapping page 28 :
# ☆Scrapping page 29 :
# ☆Scrapping page 30 :
# ☆Scrapping page 31 :
# ☆Scrapping page 32 :
# ☆Scrapping page 33 :
# ☆Scrapping page 34 :
# ☆Scrapping page 35 :
# ☆Scrapping page 36 :
# ☆Scrapping page 37 :
# ☆Scrapping page 38 :
# ☆Scrapping page 39 :
# ☆Scrapping page 40 :
# ☆Scrapping page 41 :
# ☆Scrapping page 42 :
# ☆Scrapping page 43 :
# 2021년 3월 Golang 취업, 일자리, 채용 | Indeed.com
# ★Scrapping page 0 :
# ★Scrapping page 1 :
# ★Scrapping page 2 :
# ★Scrapping page 3 :
# 127.0.0.1 - - [03/Mar/2021 17:28:29] "GET /report?word=golang HTTP/1.1" 200 -
# [{'title': 'Python Developer - Associate', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/513157'}, {'title': 'Senior Software Engineer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/513252'}, {'title': 'Software Engineering', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Hyderabad, India', 'apply_link': 'https://stackoverflow.com/jobs/513232'}, {'title': 'Lead Software Engineer, VP', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Lewisville, TX', 'apply_link': 'https://stackoverflow.com/jobs/513224'}, {'title': 'Software Engineering Java', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Glasgow, UK', 'apply_link': 'https://stackoverflow.com/jobs/513212'}, {'title': '(Senior) Fullstack Developer (m/w/d)', 'company': 'tarent solutions GmbH', 'location': 'Bonn, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/494511'}, {'title': 'Software Engineer Expert (Front End)', 'company': 'Avaloq', 'location': 'Makati, Philippines', 'apply_link': 'https://stackoverflow.com/jobs/495714'}, {'title': 'Senior Software Engineer Platform (m/f/d)', 'company': 'BASF', 'location': 'Köln, Deutschland', 'apply_link': 'https://stackoverflow.com/jobs/466262'}, {'title': 'フロントエンドエンジニア', 'company': 'HENNGE K.K.', 'location': 'Tokyo, Japan', 'apply_link': 'https://stackoverflow.com/jobs/381284'}, {'title': 'ソフトウェアエンジニア (バックエンド)', 'company': 'HENNGE K.K.', 'location': 'Tokyo, Japan', 'apply_link': 'https://stackoverflow.com/jobs/381283'}, {'title': 'Senior DevOps Engineer', 'company': 'AdformviaInvest Lithuania', 'location': 'Vilnius, Lithuania', 'apply_link': 'https://stackoverflow.com/jobs/513197'}, {'title': '(Junior) IT-System-Architekt*in im Bereich Lernmanagementsysteme', 'company': 'Technische Universität Graz', 'location': 'Graz, Österreich', 'apply_link': 'https://stackoverflow.com/jobs/513196'}, {'title': 'Front-End Software Engineer', 'company': 'HENNGE K.K.', 'location': 'Tokyo, Japan', 'apply_link': 'https://stackoverflow.com/jobs/381280'}, {'title': 'Back-End Software Engineer', 'company': 'HENNGE K.K.', 'location': 'Tokyo, Japan', 'apply_link': 'https://stackoverflow.com/jobs/380985'}, {'title': 'Software Engineering - Python Developer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/513167'}, {'title': 'Senior Software Engineer', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Mumbai, India', 'apply_link': 'https://stackoverflow.com/jobs/513150'}, {'title': 'Manager, Site reliability Engineering - Public cloud', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Bengaluru, India', 'apply_link': 'https://stackoverflow.com/jobs/513125'}, {'title': 'Sr. Observability / Telemetry Engineer- Software Engineer- VP', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Jersey City, NJ', 'apply_link': 'https://stackoverflow.com/jobs/513089'}, {'title': 'Infrastructure Development - POS Terminals', 'company': 'JPMorgan Chase Bank, N.A.', 'location': 'Tampa, FL', 'apply_link': 'https://stackoverflow.com/jobs/513071'}, {'title': 'Software Engineer', 'company': 'Secureframe', 'location': 'San Francisco, CA', 'apply_link': 'https://stackoverflow.com/jobs/495703'}, {'title': 'Senior Software Engineer', 'company': 'Secureframe', 'location': 'San Francisco, CA', 'apply_link': 'https://stackoverflow.com/jobs/495702'}, {'title': 'Devops Engineer (Associate) - Consumer Industry Cloud', 'company': 'SAP', 'location': 'Pudong, China', 'apply_link': 'https://stackoverflow.com/jobs/494228'}, {'title': 'C# Developers - Jnr/ Mid/ Snr', 'company': 'Smokeball', 'location': 'Sydney, Australia', 'apply_link': 'https://stackoverflow.com/jobs/466256'}, {'title': 'Database Administrator 3-IT', 'company': 'Oracle', 'location': 'Guadalajara, Mexico', 'apply_link': 'https://stackoverflow.com/jobs/513022'}, {'title': 'Platform Architect',  ...
